# %%
from src.rule2graph import convert_rule

# 转换Rule 110，保存到results/graphs/
convert_rule(110, output_dir='../results/graphs', verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.rule2graph import convert_rule
#       3 # 转换Rule 110，保存到results/graphs/
#       4 convert_rule(110, output_dir='../results/graphs', verbose=True)
#
# ModuleNotFoundError: No module named 'src'
